# %%
from openff.toolkit import Molecule
import pandas as pd

SDF_FILES = {
    "CDK2": "CDK2_ligand_ids.txt",
    "JNK1": "JNK1_ligand_ids.txt",
    "P38": "p38_ligand_ids.txt",
    "TYK2": "TYK2_ligand_ids.txt",
}

# %%
# Get the first molecule from each SDF and print its SMILES (and if it's charged)

smiles_by_id = {}

for target, id_file in SDF_FILES.items():
    with open(id_file, "r") as f:
        first_line = f.readline().strip()
        smiles = first_line.split()[-2]
        lig_id = first_line.split()[-1]
    molecule = Molecule.from_smiles(smiles, allow_undefined_stereo=True)
    tot_charge = sum([atom.formal_charge for atom in molecule.atoms])
    assert tot_charge == 0
    lig_id = f"{target}_{lig_id}"
    smiles_by_id[lig_id] = smiles

df = pd.DataFrame(smiles_by_id.items(), columns=["id", "smiles"])
# Save the df as a CSV
df
# Out:
#              id                                             smiles
# 0       CDK2_17  c1(nc(OC(C2(C(C(C(C(C2([H])[H])([H])[H])([H])[...
# 1  JNK1_18629-1  C(C(Oc1nc(c(c(N([H])[H])c1C#N)[H])N(C(=O)C(c1c...
# 2   P38_p38a_2n  c1(c(c(c(c(c1F)[H])[H])Oc1c(=O)n(c2c(c1[H])c(n...
# 3   TYK2_ejm_31  c1(c(c(c(c(c1[H])Cl)C(=O)N(c1c(c(nc(c1[H])N(C(...
